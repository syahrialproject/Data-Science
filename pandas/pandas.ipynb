# %% [markdown]
# ## Python Pandas

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Mengenal DataFrame

# %% [markdown]
# #### Membuat DataFrame sederhana

# %%
pd.DataFrame(data={'Minuman': ['Susu', 'Kopi'], 
                   'Harga': [4500, 3200]})
# Out:
#   Minuman  Harga
# 0    Susu   4500
# 1    Kopi   3200

# %% [markdown]
# #### Mengenal index pada DataFrame

# %%
pd.DataFrame(data={'Budi': ['suka', 'suka'], 
                   'Wati': ['tidak suka', 'suka.']},
             index=['Mangga', 'Jambu'])
# Out:
#         Budi        Wati
# Mangga  suka  tidak suka
# Jambu   suka       suka.

# %% [markdown]
# ## Mengenal Series

# %%
pd.Series(data=[100, 150, 200, 250, 300])
# Out:
# 0    100
# 1    150
# 2    200
# 3    250
# 4    300
# dtype: int64

# %%
pd.Series(data=[3000, 3500, 40000], index=['Mangga', 'Pisang', 'Jambu'], name='Harga Buah')
# Out:
# Mangga     3000
# Pisang     3500
# Jambu     40000
# Name: Harga Buah, dtype: int64

# %% [markdown]
# ## Memuat File CSV ke dalam DataFrame

# %%
wine_df = pd.read_csv('./dataset/wine_data2.csv')
wine_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
wine_df.head(10)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
# 6           6     Italy  Here's a bright, informal red that opens with ...
# 7           7    France  This dry and restrained wine offers spice in p...
# 8           8   Germany  Savory dried thyme notes accent sunnier flavor...
# 9           9    France  This has great depth of flavor with its fresh ...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                        Ars In Vitro      87   15.0     Northern Spain
# 6                             Belsito      87   16.0  Sicily & Sardinia
# 7                                 NaN      87   24.0             Alsace
# 8                               Shine      87   12.0        Rheinhessen
# 9                         Les Natures      87   27.0             Alsace
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
# 5              Navarra                NaN   Michael Schachner
# 6             Vittoria                NaN       Kerin O’Keefe
# 7               Alsace                NaN          Roger Voss
# 8                  NaN                NaN  Anna Lee C. Iijima
# 9               Alsace                NaN          Roger Voss
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 6          @kerinokeefe   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 7            @vossroger              Trimbach 2012 Gewurztraminer (Alsace)
# 8                   NaN  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...
# 9            @vossroger  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
#
#               variety               winery
# 0         White Blend              Nicosia
# 1      Portuguese Red  Quinta dos Avidagos
# 2          Pinot Gris            Rainstorm
# 3            Riesling           St. Julian
# 4          Pinot Noir         Sweet Cheeks
# 5  Tempranillo-Merlot               Tandem
# 6            Frappato      Terre di Giurfo
# 7      Gewürztraminer             Trimbach
# 8      Gewürztraminer          Heinz Eifel
# 9          Pinot Gris   Jean-Baptiste Adam

# %% [markdown]
# #### Melihat dimensi DataFrame dengan attribute ```shape```

# %%
wine_df.shape
# Out:
# (9391, 14)

# %% [markdown]
# #### Menggunakan salah satu kolom sebagai index

# %%
wine_df = pd.read_csv('./dataset/wine_data2.csv', index_col=0)
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
wine_df.shape
# Out:
# (9391, 13)

# %% [markdown]
# ## Menyimpan DataFrame ke dalam File CSV

# %%
minuman_df = pd.DataFrame(data={'Minuman': ['Bandrek', 'Kopi Hitam'], 
                                'Harga': [4500, 3200]})
minuman_df
# Out:
#       Minuman  Harga
# 0     Bandrek   4500
# 1  Kopi Hitam   3200

# %%
minuman_df.to_csv('./output/minuman.csv')

# %% [markdown]
# #### Menyimpan DataFrame ke dalam file CSV tanpa menyertakan index

# %%
minuman_df.to_csv('./output/minuman.csv', index=False)

# %% [markdown]
# ## Melakukan akses pada kolom DataFrame

# %%
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# Terdapat dua cara untuk melakukan akses kolom pada DataFrame

# %% [markdown]
# ### Cara 1: Sebagai atribute

# %%
wine_df.country
# Out:
# 0           Italy
# 1        Portugal
# 2              US
# 3              US
# 4              US
#           ...
# 9386           US
# 9387           US
# 9388           US
# 9389           US
# 9390    Argentina
# Name: country, Length: 9391, dtype: object

# %% [markdown]
# ### Cara 2: Sebagai dictionary index

# %%
wine_df['country']
# Out:
# 0           Italy
# 1        Portugal
# 2              US
# 3              US
# 4              US
#           ...
# 9386           US
# 9387           US
# 9388           US
# 9389           US
# 9390    Argentina
# Name: country, Length: 9391, dtype: object

# %%
wine_df['country'][0]
# Out:
# 'Italy'

# %% [markdown]
# ## Melakukan akses data pada DataFrame

# %% [markdown]
# Terdapat dua mekanisme untuk melakukan akses data pada DataFrame: index-based selection dan label-based selection. <br/>
# Kedua mekanisme akses ini mendahulukan baris (row) baru diikuti kolom (column).

# %% [markdown]
# ### index-based selection
# Mekanisme ini dapat dilakukan dengan memanfaatkan method ```iloc```

# %%
wine_df.iloc[0]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# winery                                                             Nicosia
# Name: 0, dtype: object

# %%
wine_df.iloc[2, 0]
# Out:
# 'US'

# %% [markdown]
# #### Slicing pada iloc

# %%
wine_df.iloc[:, 0]
# Out:
# 0           Italy
# 1        Portugal
# 2              US
# 3              US
# 4              US
#           ...
# 9386           US
# 9387           US
# 9388           US
# 9389           US
# 9390    Argentina
# Name: country, Length: 9391, dtype: object

# %%
wine_df.iloc[0, :7]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
# designation                                         Vulkà Bianco
# points                                                        87
# price                                                        NaN
# province                                       Sicily & Sardinia
# region_1                                                    Etna
# Name: 0, dtype: object

# %%
wine_df.iloc[1:3, 0]
# Out:
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %% [markdown]
# #### Melewatkan list untuk melakukan akses data pada baris dan kolom tertentu dari DataFrame

# %%
wine_df.iloc[[0, 3, 8], 0]
# Out:
# 0      Italy
# 3         US
# 8    Germany
# Name: country, dtype: object

# %% [markdown]
# #### Menggunakan negative index untuk melakukan akses data pada baris dan kolom tertentu dari DataFrame

# %%
wine_df.iloc[-5:]
# Out:
#         country                                        description  \
# 9386         US  Grown on the producer's 1,800-foot-high, dry-f...
# 9387         US  Given slightly less new oak (60%) than the pro...
# 9388         US  This is a Westside Road site known for its roc...
# 9389         US  Very dark and inky in color, this bottling by ...
# 9390  Argentina  This ultraripe Malbec-led blend suggests aged ...
#
#             designation  points  price          province  \
# 9386                NaN      93   48.0        California
# 9387                NaN      93   65.0        California
# 9388      Flax Vineyard      93   57.0        California
# 9389  My Soul Is Rested      93    NaN        California
# 9390               Alto      93   85.0  Mendoza Province
#
#                       region_1       region_2        taster_name  \
# 9386  Spring Mountain District           Napa     Virginie Boone
# 9387               Napa Valley           Napa     Virginie Boone
# 9388      Russian River Valley         Sonoma     Virginie Boone
# 9389             Central Coast  Central Coast      Matt Kettmann
# 9390                   Mendoza            NaN  Michael Schachner
#
#      taster_twitter_handle                                              title  \
# 9386               @vboone  Smith-Madrone 2012 Cabernet Sauvignon (Spring ...
# 9387               @vboone  Les Belles Collines 2012 Cabernet Sauvignon (N...
# 9388               @vboone  Merry Edwards 2013 Flax Vineyard Pinot Noir (R...
# 9389         @mattkettmann  Sanguis 2013 My Soul Is Rested Red (Central Co...
# 9390           @wineschach                 Alta Vista 2011 Alto Red (Mendoza)
#
#                  variety               winery
# 9386  Cabernet Sauvignon        Smith-Madrone
# 9387  Cabernet Sauvignon  Les Belles Collines
# 9388          Pinot Noir        Merry Edwards
# 9389           Red Blend              Sanguis
# 9390           Red Blend           Alta Vista

# %% [markdown]
# ### label-based selection
# Mekanisme ini dapat dilakukan dengan memanfaatkan method ```loc```

# %%
wine_df.loc[0, 'country']
# Out:
# 'Italy'

# %%
wine_df.loc[0:5, 'country']
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# 5       Spain
# Name: country, dtype: object

# %%
wine_df.loc[:, ['taster_name', 'taster_twitter_handle', 'points']].head()
# Out:
#           taster_name taster_twitter_handle  points
# 0       Kerin O’Keefe          @kerinokeefe      87
# 1          Roger Voss            @vossroger      87
# 2        Paul Gregutt           @paulgwine       87
# 3  Alexander Peartree                   NaN      87
# 4        Paul Gregutt           @paulgwine       87

# %% [markdown]
# ### Alternatif lain
# Alternatif lain untuk melakukan akses data dapat dilakukan dengan model akses kolom-baris (column-row)

# %%
wine_df[['country', 'province']][:].head()
# Out:
#     country           province
# 0     Italy  Sicily & Sardinia
# 1  Portugal              Douro
# 2        US             Oregon
# 3        US           Michigan
# 4        US             Oregon

# %%
wine_df[['country', 'province']][:5]
# Out:
#     country           province
# 0     Italy  Sicily & Sardinia
# 1  Portugal              Douro
# 2        US             Oregon
# 3        US           Michigan
# 4        US             Oregon

# %% [markdown]
# ## Mengganti index

# %%
wine_df.set_index('title').head()
# df = wine_df.set_index('title')
# wine_df.set_index('title', inplace=True)
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)       Tart and snappy, the flavors of lime flesh and...
# St. Julian 2013 Reserve Late Harvest Riesling (...  Pineapple rind, lemon pith and orange blossom ...
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...  Much like the regular bottling from 2012, this...
#
#                                                                            designation  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                         Vulkà Bianco
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                 Avidagos
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                      NaN
# St. Julian 2013 Reserve Late Harvest Riesling (...                Reserve Late Harvest
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...  Vintner's Reserve Wild Child Block
#
#                                                     points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                       87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)           87   15.0
# Rainstorm 2013 Pinot Gris (Willamette Valley)           87   14.0
# St. Julian 2013 Reserve Late Harvest Riesling (...      87   13.0
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...      87   65.0
#
#                                                              province  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Sicily & Sardinia
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                   Douro
# Rainstorm 2013 Pinot Gris (Willamette Valley)                  Oregon
# St. Julian 2013 Reserve Late Harvest Riesling (...           Michigan
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...             Oregon
#
#                                                                region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                  Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                       NaN
# Rainstorm 2013 Pinot Gris (Willamette Valley)         Willamette Valley
# St. Julian 2013 Reserve Late Harvest Riesling (...  Lake Michigan Shore
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...    Willamette Valley
#
#                                                              region_2  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                 NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                     NaN
# Rainstorm 2013 Pinot Gris (Willamette Valley)       Willamette Valley
# St. Julian 2013 Reserve Late Harvest Riesling (...                NaN
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...  Willamette Valley
#
#                                                            taster_name  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                        Kerin O’Keefe
# Quinta dos Avidagos 2011 Avidagos Red (Douro)               Roger Voss
# Rainstorm 2013 Pinot Gris (Willamette Valley)             Paul Gregutt
# St. Julian 2013 Reserve Late Harvest Riesling (...  Alexander Peartree
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        Paul Gregutt
#
#                                                    taster_twitter_handle  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                           @kerinokeefe
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                 @vossroger
# Rainstorm 2013 Pinot Gris (Willamette Valley)                @paulgwine
# St. Julian 2013 Reserve Late Harvest Riesling (...                   NaN
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           @paulgwine
#
#                                                            variety  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      White Blend
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portuguese Red
# Rainstorm 2013 Pinot Gris (Willamette Valley)           Pinot Gris
# St. Julian 2013 Reserve Late Harvest Riesling (...        Riesling
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...      Pinot Noir
#
#                                                                  winery
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                               Nicosia
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Quinta dos Avidagos
# Rainstorm 2013 Pinot Gris (Willamette Valley)                 Rainstorm
# St. Julian 2013 Reserve Late Harvest Riesling (...           St. Julian
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...         Sweet Cheeks

# %%
wine_df.reset_index().head()
# Out:
#    index   country                                        description  \
# 0      0     Italy  Aromas include tropical fruit, broom, brimston...
# 1      1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2      2        US  Tart and snappy, the flavors of lime flesh and...
# 3      3        US  Pineapple rind, lemon pith and orange blossom ...
# 4      4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# ## Seleksi data pada DataFrame
# #### (Conditional Selection)

# %%
wine_df['country'] == 'Italy'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9386    False
# 9387    False
# 9388    False
# 9389    False
# 9390    False
# Name: country, Length: 9391, dtype: bool

# %%
wine_df.loc[wine_df['country'] == 'Italy'].head()
# Out:
#    country                                        description   designation  \
# 0    Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 6    Italy  Here's a bright, informal red that opens with ...       Belsito
# 13   Italy  This is dominated by oak and oak-driven aromas...         Rosso
# 22   Italy  Delicate aromas recall white flower and citrus...     Ficiligno
# 24   Italy  Aromas of prune, blackcurrant, toast and oak c...         Aynat
#
#     points  price           province  region_1 region_2    taster_name  \
# 0       87    NaN  Sicily & Sardinia      Etna      NaN  Kerin O’Keefe
# 6       87   16.0  Sicily & Sardinia  Vittoria      NaN  Kerin O’Keefe
# 13      87    NaN  Sicily & Sardinia      Etna      NaN  Kerin O’Keefe
# 22      87   19.0  Sicily & Sardinia   Sicilia      NaN  Kerin O’Keefe
# 24      87   35.0  Sicily & Sardinia   Sicilia      NaN  Kerin O’Keefe
#
#    taster_twitter_handle                                              title  \
# 0           @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 6           @kerinokeefe   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 13          @kerinokeefe             Masseria Setteporte 2012 Rosso  (Etna)
# 22          @kerinokeefe  Baglio di Pianetto 2007 Ficiligno White (Sicilia)
# 24          @kerinokeefe        Canicattì 2009 Aynat Nero d'Avola (Sicilia)
#
#               variety               winery
# 0         White Blend              Nicosia
# 6            Frappato      Terre di Giurfo
# 13  Nerello Mascalese  Masseria Setteporte
# 22        White Blend   Baglio di Pianetto
# 24       Nero d'Avola            Canicattì

# %%
wine_df.loc[(wine_df['country'] == 'Italy') & (wine_df['points'] >= 90)].head()
# Out:
#     country                                        description  \
# 120   Italy  Slightly backward, particularly given the vint...
# 130   Italy  At the first it was quite muted and subdued, b...
# 133   Italy  Einaudi's wines have been improving lately, an...
# 135   Italy  The color is just beginning to show signs of b...
# 140   Italy  A big, fat, luscious wine with plenty of toast...
#
#                designation  points  price  province        region_1 region_2  \
# 120    Bricco Rocche Prapó      92   70.0  Piedmont          Barolo      NaN
# 130  Bricco Rocche Brunate      91   70.0  Piedmont          Barolo      NaN
# 133                    NaN      91   68.0  Piedmont          Barolo      NaN
# 135                 Sorano      91   60.0  Piedmont          Barolo      NaN
# 140            Costa Bruna      90   26.0  Piedmont  Barbera d'Alba      NaN
#
#     taster_name taster_twitter_handle  \
# 120         NaN                   NaN
# 130         NaN                   NaN
# 133         NaN                   NaN
# 135         NaN                   NaN
# 140         NaN                   NaN
#
#                                                title   variety  \
# 120       Ceretto 2003 Bricco Rocche Prapó  (Barolo)  Nebbiolo
# 130     Ceretto 2003 Bricco Rocche Brunate  (Barolo)  Nebbiolo
# 133                Poderi Luigi Einaudi 2003  Barolo  Nebbiolo
# 135            Giacomo Ascheri 2001 Sorano  (Barolo)  Nebbiolo
# 140  Poderi Colla 2005 Costa Bruna  (Barbera d'Alba)   Barbera
#
#                    winery
# 120               Ceretto
# 130               Ceretto
# 133  Poderi Luigi Einaudi
# 135       Giacomo Ascheri
# 140          Poderi Colla

# %%
wine_df[(wine_df['country'] == 'Italy') & (wine_df['points'] >= 90)].head()
# Out:
#     country                                        description  \
# 120   Italy  Slightly backward, particularly given the vint...
# 130   Italy  At the first it was quite muted and subdued, b...
# 133   Italy  Einaudi's wines have been improving lately, an...
# 135   Italy  The color is just beginning to show signs of b...
# 140   Italy  A big, fat, luscious wine with plenty of toast...
#
#                designation  points  price  province        region_1 region_2  \
# 120    Bricco Rocche Prapó      92   70.0  Piedmont          Barolo      NaN
# 130  Bricco Rocche Brunate      91   70.0  Piedmont          Barolo      NaN
# 133                    NaN      91   68.0  Piedmont          Barolo      NaN
# 135                 Sorano      91   60.0  Piedmont          Barolo      NaN
# 140            Costa Bruna      90   26.0  Piedmont  Barbera d'Alba      NaN
#
#     taster_name taster_twitter_handle  \
# 120         NaN                   NaN
# 130         NaN                   NaN
# 133         NaN                   NaN
# 135         NaN                   NaN
# 140         NaN                   NaN
#
#                                                title   variety  \
# 120       Ceretto 2003 Bricco Rocche Prapó  (Barolo)  Nebbiolo
# 130     Ceretto 2003 Bricco Rocche Brunate  (Barolo)  Nebbiolo
# 133                Poderi Luigi Einaudi 2003  Barolo  Nebbiolo
# 135            Giacomo Ascheri 2001 Sorano  (Barolo)  Nebbiolo
# 140  Poderi Colla 2005 Costa Bruna  (Barbera d'Alba)   Barbera
#
#                    winery
# 120               Ceretto
# 130               Ceretto
# 133  Poderi Luigi Einaudi
# 135       Giacomo Ascheri
# 140          Poderi Colla

# %% [markdown]
# ## Mengenal beberapa built-in method
# #### Mengenal method ```isin```

# %%
wine_df.loc[wine_df['country'].isin(['Italy', 'France'])].head()
# Out:
#    country                                        description   designation  \
# 0    Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 6    Italy  Here's a bright, informal red that opens with ...       Belsito
# 7   France  This dry and restrained wine offers spice in p...           NaN
# 9   France  This has great depth of flavor with its fresh ...   Les Natures
# 11  France  This is a dry wine, very spicy, with a tight, ...           NaN
#
#     points  price           province  region_1 region_2    taster_name  \
# 0       87    NaN  Sicily & Sardinia      Etna      NaN  Kerin O’Keefe
# 6       87   16.0  Sicily & Sardinia  Vittoria      NaN  Kerin O’Keefe
# 7       87   24.0             Alsace    Alsace      NaN     Roger Voss
# 9       87   27.0             Alsace    Alsace      NaN     Roger Voss
# 11      87   30.0             Alsace    Alsace      NaN     Roger Voss
#
#    taster_twitter_handle                                              title  \
# 0           @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 6           @kerinokeefe   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 7             @vossroger              Trimbach 2012 Gewurztraminer (Alsace)
# 9             @vossroger  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
# 11            @vossroger            Leon Beyer 2012 Gewurztraminer (Alsace)
#
#            variety              winery
# 0      White Blend             Nicosia
# 6         Frappato     Terre di Giurfo
# 7   Gewürztraminer            Trimbach
# 9       Pinot Gris  Jean-Baptiste Adam
# 11  Gewürztraminer          Leon Beyer

# %% [markdown]
# #### Mengenal method ```isna``` dan ```notna```

# %%
wine_df[wine_df['price'].isna()].head()
# Out:
#    country                                        description  \
# 0    Italy  Aromas include tropical fruit, broom, brimston...
# 13   Italy  This is dominated by oak and oak-driven aromas...
# 30  France  Red cherry fruit comes laced with light tannin...
# 31   Italy  Merlot and Nero d'Avola form the base for this...
# 32   Italy  Part of the extended Calanìca series, this Gri...
#
#                      designation  points  price           province  \
# 0                   Vulkà Bianco      87    NaN  Sicily & Sardinia
# 13                         Rosso      87    NaN  Sicily & Sardinia
# 30                       Nouveau      86    NaN         Beaujolais
# 31  Calanìca Nero d'Avola-Merlot      86    NaN  Sicily & Sardinia
# 32      Calanìca Grillo-Viognier      86    NaN  Sicily & Sardinia
#
#                region_1 region_2    taster_name taster_twitter_handle  \
# 0                  Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 13                 Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 30  Beaujolais-Villages      NaN     Roger Voss            @vossroger
# 31              Sicilia      NaN            NaN                   NaN
# 32              Sicilia      NaN            NaN                   NaN
#
#                                                 title            variety  \
# 0                   Nicosia 2013 Vulkà Bianco  (Etna)        White Blend
# 13             Masseria Setteporte 2012 Rosso  (Etna)  Nerello Mascalese
# 30  Domaine de la Madone 2012 Nouveau  (Beaujolais...              Gamay
# 31  Duca di Salaparuta 2010 Calanìca Nero d'Avola-...          Red Blend
# 32  Duca di Salaparuta 2011 Calanìca Grillo-Viogni...        White Blend
#
#                   winery
# 0                Nicosia
# 13   Masseria Setteporte
# 30  Domaine de la Madone
# 31    Duca di Salaparuta
# 32    Duca di Salaparuta

# %%
wine_df[wine_df['price'].notna()].head()
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
# 5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 1                            Avidagos      87   15.0           Douro
# 2                                 NaN      87   14.0          Oregon
# 3                Reserve Late Harvest      87   13.0        Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
# 5              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery
# 1      Portuguese Red  Quinta dos Avidagos
# 2          Pinot Gris            Rainstorm
# 3            Riesling           St. Julian
# 4          Pinot Noir         Sweet Cheeks
# 5  Tempranillo-Merlot               Tandem

# %% [markdown]
# ## Menambah kolom baru pada DataFrame

# %% [markdown]
# Mendata seluruh kolom yang tersedia dengan attribute ```columns```

# %%
wine_df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# Menambah kolom baru dengan nama ```critic``` dan diberi nilai ```everyone``` untuk tiap baris.

# %%
wine_df['critic'] = 'everyone'
wine_df['critic'].head(10)
# Out:
# 0    everyone
# 1    everyone
# 2    everyone
# 3    everyone
# 4    everyone
# 5    everyone
# 6    everyone
# 7    everyone
# 8    everyone
# 9    everyone
# Name: critic, dtype: object

# %%
wine_df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery', 'critic'],
#       dtype='object')

# %% [markdown]
# Menambah kolom baru dengan nama ```index_backwards``` dan diberi nilai bilangan bulat dari besar ke kecil sesuai dengan banyaknya jumlah baris.

# %%
wine_df['index_backwards'] = range(len(wine_df), 0, -1)
wine_df['index_backwards'].head()
# Out:
# 0    9391
# 1    9390
# 2    9389
# 3    9388
# 4    9387
# Name: index_backwards, dtype: int32

# %% [markdown]
# ## Menghasilkan ringkasan (summary) data pada DataFrame

# %% [markdown]
# #### Mengenal method ```describe```, ```mean```,  ```unique```, ```value_counts```

# %%
wine_df.describe()
# Out:
#             points        price  index_backwards
# count  9391.000000  8747.000000      9391.000000
# mean     88.338409    35.361152      4696.000000
# std       2.985455    45.102693      2711.092523
# min      80.000000     4.000000         1.000000
# 25%      86.000000    17.000000      2348.500000
# 50%      88.000000    25.000000      4696.000000
# 75%      90.000000    42.000000      7043.500000
# max     100.000000  1900.000000      9391.000000

# %%
wine_df['points'].describe()
# Out:
# count    9391.000000
# mean       88.338409
# std         2.985455
# min        80.000000
# 25%        86.000000
# 50%        88.000000
# 75%        90.000000
# max       100.000000
# Name: points, dtype: float64

# %%
wine_df['points'].mean()
# Out:
# 88.33840911511021

# %%
wine_df['taster_name'].describe()
# Out:
# count           7487
# unique            18
# top       Roger Voss
# freq            1833
# Name: taster_name, dtype: object

# %%
wine_df['taster_name'].unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams'], dtype=object)

# %%
wine_df['taster_name'].value_counts().head()
# Out:
# Roger Voss           1833
# Michael Schachner    1140
# Kerin O’Keefe         812
# Virginie Boone        727
# Paul Gregutt          669
# Name: taster_name, dtype: int64

# %% [markdown]
# ## Mengenal Mapping
# Terdapat dua mekanisme mapping pada DataFrame, yaitu: dengan memanfaatkan method ```map``` dan method ```apply```

# %% [markdown]
# ### Mengenal method ```map```
# Diterapkan di tingkat Series

# %%
points_mean = wine_df['points'].mean()
wine_df['points'].map(lambda p: p - points_mean)
# Out:
# 0      -1.338409
# 1      -1.338409
# 2      -1.338409
# 3      -1.338409
# 4      -1.338409
#           ...
# 9386    4.661591
# 9387    4.661591
# 9388    4.661591
# 9389    4.661591
# 9390    4.661591
# Name: points, Length: 9391, dtype: float64

# %% [markdown]
# ### Mengenal method ```apply```
# Diterapkan di tingkat DataFrame

# %%
points_mean = wine_df['points'].mean()

def remean_points(row):
    row['points'] = row['points'] - points_mean
    return row

wine_df.apply(remean_points, axis='columns').head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.338409    NaN  Sicily & Sardinia
# 1                            Avidagos -1.338409   15.0              Douro
# 2                                 NaN -1.338409   14.0             Oregon
# 3                Reserve Late Harvest -1.338409   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block -1.338409   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery    critic  index_backwards
# 0     White Blend              Nicosia  everyone             9391
# 1  Portuguese Red  Quinta dos Avidagos  everyone             9390
# 2      Pinot Gris            Rainstorm  everyone             9389
# 3        Riesling           St. Julian  everyone             9388
# 4      Pinot Noir         Sweet Cheeks  everyone             9387

# %% [markdown]
# ### Alternatif lain dengan built-in operations
# Mekanisme ini lebih cepat dan efisien (bila dibandingkan ```map``` dan ```apply```) tetapi tidak bisa menangani pemrosesan yang kompleks.

# %%
points_mean = wine_df['points'].mean()
wine_df['points'] - points_mean
# Out:
# 0      -1.338409
# 1      -1.338409
# 2      -1.338409
# 3      -1.338409
# 4      -1.338409
#           ...
# 9386    4.661591
# 9387    4.661591
# 9388    4.661591
# 9389    4.661591
# 9390    4.661591
# Name: points, Length: 9391, dtype: float64

# %%
wine_df['country'] + ' - ' + wine_df['region_1']
# Out:
# 0                        Italy - Etna
# 1                                 NaN
# 2              US - Willamette Valley
# 3            US - Lake Michigan Shore
# 4              US - Willamette Valley
#                     ...
# 9386    US - Spring Mountain District
# 9387                 US - Napa Valley
# 9388        US - Russian River Valley
# 9389               US - Central Coast
# 9390              Argentina - Mendoza
# Length: 9391, dtype: object

# %% [markdown]
# #### Kasus: Mencari title wine dengan proporsi points/price tertinggi dengan memanfaatkan method ```idmax```

# %%
wine_df.loc[(wine_df['points']/wine_df['price']).idxmax(), 'title']
# Out:
# 'Felix Solis 2013 Flirty Bird Syrah (Vino de la Tierra de Castilla)'

# %%
wine_df['title'][(wine_df['points']/wine_df['price']).idxmax()]
# Out:
# 'Felix Solis 2013 Flirty Bird Syrah (Vino de la Tierra de Castilla)'

# %% [markdown]
# Kasus: Mencari jumlah wine dengan description tropical dan fruity. Siapkan series untuk menampung jumlah dari kedua data.

# %%
n_tropical = wine_df['description'].map(lambda desc: 'tropical' in desc).sum()
n_fruity = wine_df['description'].map(lambda desc: 'fruity' in desc).sum()
pd.Series([n_tropical, n_fruity], index=['tropical', 'fruity'])
# Out:
# tropical    272
# fruity      654
# dtype: int64

# %% [markdown]
# #### Kasus: Melakukan konversi point menjadi star

# %%
def star_converter(row):
    if row['country'] == 'Canada':
        row['star'] = 3
    elif row['points'] >= 95:
        row['star'] = 3
    elif row['points'] >= 85:
        row['star'] = 2
    else:
        row['star'] = 1
    return row

wine_df['star'] = None
wine_df.apply(star_converter, axis='columns').head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery    critic  index_backwards  star
# 0     White Blend              Nicosia  everyone             9391     2
# 1  Portuguese Red  Quinta dos Avidagos  everyone             9390     2
# 2      Pinot Gris            Rainstorm  everyone             9389     2
# 3        Riesling           St. Julian  everyone             9388     2
# 4      Pinot Noir         Sweet Cheeks  everyone             9387     2

# %% [markdown]
# ## Analisis terhadap sekelompok data

# %% [markdown]
# #### Kasus: menghitung jumlah data (rows/baris) untuk tiap points. <br/>
# Cara pertama: dengan memanfaatkan method ```value_counts```

# %%
wine_df['points'].value_counts().head()
# Out:
# 87    1349
# 88    1305
# 90    1040
# 86     935
# 89     866
# Name: points, dtype: int64

# %% [markdown]
# Cara kedua: mengelompokkan data pada DataFrame terlebih dahulu dengan memanfaatkan method ```groupby```

# %%
wine_df.groupby('points')['points'].count().head()
# Out:
# points
# 80     16
# 81     42
# 82    117
# 83    256
# 84    450
# Name: points, dtype: int64

# %% [markdown]
# #### Kasus: mendata wine reviewer beserta jumlah review yang pernah dilakukan.
# Reviewer dapat diidentifikasi melalui kolom ```taster_name```

# %%
wine_df.groupby('taster_name')['taster_name'].count().head()
# Out:
# taster_name
# Alexander Peartree     40
# Anna Lee C. Iijima    280
# Anne Krebiehl MW      204
# Carrie Dykes            6
# Fiona Adams             3
# Name: taster_name, dtype: int64

# %% [markdown]
# #### Kasus: mencari harga terrendah dari setiap kelompok point

# %%
wine_df.groupby('points')['price'].min().head()
# Out:
# points
# 80    8.0
# 81    7.0
# 82    6.0
# 83    5.0
# 84    5.0
# Name: price, dtype: float64

# %% [markdown]
# #### Kasus: menampilkan title dari wine untuk tiap country dengan points tertinggi
# Data wine akan dikelompokkan terlebih dahulu berdasarkan negara, selanjutnya akan dicari wine di tiap kelompok negara yang memiliki points tertinggi

# %%
wine_df.groupby('country').apply(lambda df: df[ df['points'] == df['points'].max() ])[['title']].head()
# Out:
#                                                             title
# country
# Argentina 8869  Pascual Toso 2014 Finca Pedregal Single Vineya...
# Armenia   8170     Van Ardi 2015 Estate Bottled Kangoun (Armenia)
# Australia 345   Chambers Rosewood Vineyards NV Rare Muscat (Ru...
# Austria   6736  Emmerich Knoll 2008 Ried Loibenberg Smaragd Gr...
#           7864  Rosenhof 2012 Orion Eiswein Grüner Veltliner (...

# %% [markdown]
# #### Kasus: menampilkan title dari wine untuk tiap proviince di tiap country dengan points tertinggi

# %%
wine_df.groupby(['country','province']).apply(lambda df: df[ df['points'] == df['points'].max() ])[['title']].head()
# Out:
#                                                                              title
# country   province
# Argentina Mendoza Province 8869  Pascual Toso 2014 Finca Pedregal Single Vineya...
#           Other            4633  El Esteco 2013 Chañar Punco Red (Calchaquí Val...
# Armenia   Armenia          8170     Van Ardi 2015 Estate Bottled Kangoun (Armenia)
# Australia Australia Other  893   Hungerford Hill 2008 Heavy Metal Shiraz (South...
#           New South Wales  5290            Hope Estate 2009 Shiraz (Hunter Valley)

# %% [markdown]
# ### Mengenal method ```agg```

# %%
wine_df.groupby('country')['price'].agg([len, min, max]).head()
# Out:
#              len   min    max
# country
# Argentina  289.0   6.0  215.0
# Armenia      1.0  14.0   14.0
# Australia  183.0   7.0  350.0
# Austria    225.0  10.0   90.0
# Brazil       2.0  31.0   36.0

# %% [markdown]
# #### Kasus: menampilkan harga (```price```) terrendah dan tertinggi untuk setiap jenis wine (```variety```)

# %%
wine_df.groupby('variety')['price'].agg(['min', 'max']).head()
# Out:
#               min   max
# variety
# Agiorgitiko  15.0  25.0
# Aglianico    17.0  66.0
# Albana       14.0  25.0
# Albanello    20.0  20.0
# Albariño     12.0  60.0

# %% [markdown]
# ## Mengenal pengurutan data (sorting)

# %% [markdown]
# Membuat DataFrame yang lebih sederhana dengan tiga kolom

# %%
wine_simple_df = wine_df[['country', 'title', 'price']]
wine_simple_df.head()
# Out:
#     country                                              title  price
# 0     Italy                  Nicosia 2013 Vulkà Bianco  (Etna)    NaN
# 1  Portugal      Quinta dos Avidagos 2011 Avidagos Red (Douro)   15.0
# 2        US      Rainstorm 2013 Pinot Gris (Willamette Valley)   14.0
# 3        US  St. Julian 2013 Reserve Late Harvest Riesling ...   13.0
# 4        US  Sweet Cheeks 2012 Vintner's Reserve Wild Child...   65.0

# %% [markdown]
# #### Mengurutkan data berdasarkan price

# %%
wine_simple_df.sort_values(by='price').head()
# Out:
#        country                                              title  price
# 1987     Spain  Felix Solis 2013 Flirty Bird Syrah (Vino de la...    4.0
# 3950  Portugal  Adega Cooperativa Ponte de Barca 2010 Escolha ...    5.0
# 7605     Chile  San Pedro 2002 Gato Negro Cabernet Sauvignon (...    5.0
# 3167     Italy                   Anna Spinato NV Mini  (Prosecco)    5.0
# 8428        US  Earth's Harvest 2014 Organic Grapes Chardonnay...    5.0

# %% [markdown]
# #### Pengurutan secara descending (dari nilai terbesar ke nilai terkecil)

# %%
wine_simple_df.sort_values(by='price', ascending=False).head()
# Out:
#       country                                              title   price
# 1558   France                      Château Margaux 2009  Margaux  1900.0
# 1575   France           Château Mouton Rothschild 2009  Pauillac  1300.0
# 1571   France            Château Haut-Brion 2009  Pessac-Léognan  1200.0
# 1566   France  Château La Mission Haut-Brion 2009  Pessac-Léo...  1100.0
# 347   Germany  Robert Weil 2014 Kiedrich Gräfenberg Trockenbe...   775.0

# %%
wine_simple_df.sort_values(by=['country', 'title']).head()
# Out:
#         country                                       title  price
# 5902  Argentina                  2 Copas 2009 Red (Mendoza)    8.0
# 7076  Argentina        Achaval-Ferrer 2007 Malbec (Mendoza)   29.0
# 6287  Argentina  Acordeón 2012 Cabernet Sauvignon (Mendoza)    9.0
# 183   Argentina               Alamos 2007 Torrontés (Salta)   12.0
# 1851  Argentina                   Alamos 2013 Red (Mendoza)   13.0

# %% [markdown]
# #### Kasus: menampilkan daftar harga terrendah dan tertinggi untuk setiap variety wine, data diurutkan secara descending berdasarkan harga terrendah dan diikuti harga tertinggi.

# %%
wine_df.groupby('variety')['price'].agg(['min', 'max']).sort_values(by=['min','max'], ascending=False).head()
# Out:
#               min    max
# variety
# Muscadelle  350.0  350.0
# Tokaji      175.0  175.0
# Aleatico     55.0   55.0
# Moscadello   55.0   55.0
# Cerceal      50.0   50.0

# %% [markdown]
# #### Kasus: menampilkan rata-rata points yang diberikan oleh tiap reviewer (```taster_name```)

# %%
wine_df.groupby('taster_name')['points'].mean().head()
# Out:
# taster_name
# Alexander Peartree    85.825000
# Anna Lee C. Iijima    88.267857
# Anne Krebiehl MW      90.186275
# Carrie Dykes          86.333333
# Fiona Adams           86.333333
# Name: points, dtype: float64

# %% [markdown]
# #### Kasus: menampilkan jumlah wine (```title```) yang dihasilkan di tiap negara (```country```) untuk tiap jenis wine (```variety```)

# %%
wine_df.groupby(['country', 'variety'])['title'].count().sort_values(ascending=False).head(10)
# Out:
# country   variety
# US        Pinot Noir                  708
#           Cabernet Sauvignon          551
#           Chardonnay                  494
# France    Bordeaux-style Red Blend    346
# Italy     Red Blend                   266
# US        Syrah                       245
#           Red Blend                   212
# Italy     Nebbiolo                    204
# Portugal  Portuguese Red              190
# France    Chardonnay                  189
# Name: title, dtype: int64

# %% [markdown]
# ## Mengubah nama kolom pada DataFrame
# Perubahan nama kolom pada DataFrame dapat dilakukan dengan memanfaatkan method ```rename```

# %%
wine_df.rename(columns={'points': 'score'}).head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# 2                                 NaN     87   14.0             Oregon
# 3                Reserve Late Harvest     87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block     87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery    critic  index_backwards  star
# 0     White Blend              Nicosia  everyone             9391  None
# 1  Portuguese Red  Quinta dos Avidagos  everyone             9390  None
# 2      Pinot Gris            Rainstorm  everyone             9389  None
# 3        Riesling           St. Julian  everyone             9388  None
# 4      Pinot Noir         Sweet Cheeks  everyone             9387  None

# %% [markdown]
# #### Mengubah label/nama index dengan method ```rename_axis```

# %%
wine_df.rename_axis('baris', axis='rows').head()
# Out:
#         country                                        description  \
# baris
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
#
#                               designation  points  price           province  \
# baris
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# 2                                     NaN      87   14.0             Oregon
# 3                    Reserve Late Harvest      87   13.0           Michigan
# 4      Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                   region_1           region_2         taster_name  \
# baris
# 0                     Etna                NaN       Kerin O’Keefe
# 1                      NaN                NaN          Roger Voss
# 2        Willamette Valley  Willamette Valley        Paul Gregutt
# 3      Lake Michigan Shore                NaN  Alexander Peartree
# 4        Willamette Valley  Willamette Valley        Paul Gregutt
#
#       taster_twitter_handle  \
# baris
# 0              @kerinokeefe
# 1                @vossroger
# 2               @paulgwine
# 3                       NaN
# 4               @paulgwine
#
#                                                    title         variety  \
# baris
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1          Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2          Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3      St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4      Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                     winery    critic  index_backwards  star
# baris
# 0                  Nicosia  everyone             9391  None
# 1      Quinta dos Avidagos  everyone             9390  None
# 2                Rainstorm  everyone             9389  None
# 3               St. Julian  everyone             9388  None
# 4             Sweet Cheeks  everyone             9387  None

# %%
wine_df.rename_axis('baris', axis='rows').rename_axis('kolom', axis='columns').head()
# Out:
# kolom   country                                        description  \
# baris
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
#
# kolom                         designation  points  price           province  \
# baris
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# 2                                     NaN      87   14.0             Oregon
# 3                    Reserve Late Harvest      87   13.0           Michigan
# 4      Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
# kolom             region_1           region_2         taster_name  \
# baris
# 0                     Etna                NaN       Kerin O’Keefe
# 1                      NaN                NaN          Roger Voss
# 2        Willamette Valley  Willamette Valley        Paul Gregutt
# 3      Lake Michigan Shore                NaN  Alexander Peartree
# 4        Willamette Valley  Willamette Valley        Paul Gregutt
#
# kolom taster_twitter_handle  \
# baris
# 0              @kerinokeefe
# 1                @vossroger
# 2               @paulgwine
# 3                       NaN
# 4               @paulgwine
#
# kolom                                              title         variety  \
# baris
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1          Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2          Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3      St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4      Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
# kolom               winery    critic  index_backwards  star
# baris
# 0                  Nicosia  everyone             9391  None
# 1      Quinta dos Avidagos  everyone             9390  None
# 2                Rainstorm  everyone             9389  None
# 3               St. Julian  everyone             9388  None
# 4             Sweet Cheeks  everyone             9387  None
